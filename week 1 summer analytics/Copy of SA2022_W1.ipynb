# %% [markdown]
# # SUMMER ANALYTICS 2022

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2022! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
df =pd.read_csv("/SA2022_W1_Pokemon.csv")

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
del df['#']

df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
df.set_index('Name')
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
df['combo'] =df['Type 1'] + '+' + df['Type 2'].astype(str)
df['combo'].value_counts()['Psychic+Flying']
# Out:
# 6

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
count=df['Type 1'].str.count('Flying')
count.sum()
# Out:
# 4

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
df['Sp. Def'].std()
# Out:
# 27.82891579711745

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
lez=df['Legendary'].value_counts()[True]
cal =lez/800
cal
# Out:
# 0.08125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
max = df['Defense'].max()
max
# Out:
# 230

# %%
df.loc[df['Defense'] == 230]
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 224  SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# 230              Shuckle    Bug    Rock    505  20      10      230       10
# 333    AggronMega Aggron  Steel     NaN    630  70     140      230       60
#
#      Sp. Def  Speed  Generation  Legendary         combo
# 224       95     30           2      False  Steel+Ground
# 230      230      5           2      False      Bug+Rock
# 333       80     50           3      False     Steel+nan

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
response = df[df['Type 2'] == 'Poison'].iloc[0:800]['Attack']
index_num =response.idxmax()
strongest_poison_pokemon_index = index_num
# Out:
# 0       49
# 1       62
# 2       82
# 3      100
# 16      35
# 17      25
# 18      90
# 19     150
# 48      50
# 49      65
# 50      80
# 53      55
# 54      65
# 75      75
# 76      90
# 77     105
# 78      40
# 79      70
# 99      35
# 100     50
# 101     65
# 102     65
# 181     60
# 182     90
# 227     95
# 292     50
# 344     60
# 451     30
# 452     70
# 603     45
# 604     55
# 605    100
# 651     55
# 652     85
# Name: Attack, dtype: int64

# %%
row = df.iloc[strongest_poison_pokemon_index]
row
# Out:
# Name          BeedrillMega Beedrill
# Type 1                          Bug
# Type 2                       Poison
# Total                           495
# HP                               65
# Attack                          150
# Defense                          40
# Sp. Atk                          15
# Sp. Def                          80
# Speed                           145
# Generation                        1
# Legendary                     False
# combo                    Bug+Poison
# Name: 19, dtype: object

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
sns.relplot(data=df)
plt.title('Pokedex')
plt.ylabel('index number')
plt.show()

# %%
sns.stripplot(data=df)

plt.title('Pokedex')
plt.ylabel('index number')
plt.show()

# %%
sns.barplot(data=df)
plt.title('Pokedex')
plt.ylabel('index number')
plt.show()

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
Ghost = df[df['Type 1'] == 'Ghost'].iloc[0:800]['Name']

# %%
 faster_ghost_pokemon_index =df[df['Type 1'] == 'Ghost'].iloc[0:800]['Speed']
 faster_ghost_pokemon_index
# Out:
# 99      80
# 100     95
# 101    110
# 102    130
# 215     85
# 385     45
# 386     65
# 387     75
# 388     25
# 389     25
# 472     70
# 473     80
# 477    105
# 490     35
# 529     45
# 544     90
# 545     90
# 623     30
# 624     30
# 668     20
# 669     55
# 670     80
# 778     38
# 779     56
# 780     51
# 781     56
# 782     46
# 783     41
# 784     84
# 785     99
# 786     69
# 787     54
# Name: Speed, dtype: int64

# %%
 faster_ghost_pokemon_index =df[df['Type 1'] == 'Ghost'].iloc[0:800]['Speed']
 index_num =faster_ghost_pokemon_index.idxmax()
 faster_ghost_pokemon = df.iloc[index_num]
 faster_ghost_pokemon
# Out:
# Name          GengarMega Gengar
# Type 1                    Ghost
# Type 2                   Poison
# Total                       600
# HP                           60
# Attack                       65
# Defense                      80
# Sp. Atk                     170
# Sp. Def                      95
# Speed                       130
# Generation                    1
# Legendary                 False
# combo              Ghost+Poison
# Name: 102, dtype: object

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
stronger_indef_weaker_inattack= df.loc[(df['Attack']<84) & (df['Defense']>78)&(df['Legendary']==False)]

# %%
stronger_indef_weaker_inattack.shape[0]
# Out:
# 116

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, here are some bonus questions that you can try to further deepen your understanding of the topic!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
